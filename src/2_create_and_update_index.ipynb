# %%
# %pip install -q azure-search-documents python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.search.documents.indexes.models import (
    SimpleField,
    SearchFieldDataType,
    SearchableField,
    SearchField,
    VectorSearch,
    HnswAlgorithmConfiguration,
    VectorSearchProfile,
    SearchIndex,
)
import os
from dotenv import load_dotenv

load_dotenv()

index_name = os.getenv("SEARCH_INDEX_NAME")
vector_search_profile_name = f"{index_name}_profile"

fields = [
    SimpleField(name="id",               type=SearchFieldDataType.String, key=True),
    SearchableField(name="review_text",  type=SearchFieldDataType.String, analyzer_name="en.lucene"),
    SearchableField(name="review_title", type=SearchFieldDataType.String, analyzer_name="en.lucene"),
    SimpleField(name="dateAdded",        type=SearchFieldDataType.DateTimeOffset, filterable=True, sortable=True),
    SimpleField(name="city",             type=SearchFieldDataType.String,         filterable=True),
    SimpleField(name="hotel_name",       type=SearchFieldDataType.String,         filterable=True),
    SimpleField(name="hotel_state",      type=SearchFieldDataType.String,         filterable=True),
    SearchField(
        name="embedding",
        type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
        vector_search_dimensions=1536,  # Adjust this to match your embedding size
        vector_search_profile_name=vector_search_profile_name,
    ),
]

# Vector search configuration
hnsw_algorithm_name = f"{index_name}_hnsw"
vector_search = VectorSearch(
        algorithms=[HnswAlgorithmConfiguration(name=hnsw_algorithm_name)],
        profiles=[
            VectorSearchProfile(
                name=vector_search_profile_name,
                algorithm_configuration_name=hnsw_algorithm_name,
            )
        ],
    )

index = SearchIndex(name=index_name, fields=fields, vector_search=vector_search)

# %%
from azure.core.credentials import AzureKeyCredential
from azure.search.documents.indexes import SearchIndexClient

import os
from dotenv import load_dotenv

load_dotenv()

# Azure Search service details
service_name = os.getenv("SERVICE_NAME")
admin_key = os.getenv("SEARCH_ADMIN_KEY")
index_name = os.getenv("SEARCH_INDEX_NAME")

# Initialize the search index client
endpoint = f"https://{service_name}.search.windows.net/"
credential = AzureKeyCredential(admin_key)
index_client = SearchIndexClient(endpoint=endpoint, credential=credential)

# %%
import os
import json
from azure.search.documents import SearchClient


# Create the index
index_client.create_or_update_index(index)

# Initialize the search client
search_client = SearchClient(endpoint=endpoint, index_name=index_name, credential=credential)

# Function to read and process JSON files
def process_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    
    # Ensure the embedding is a list of floats
    data['embedding'] = [float(x) for x in data['embedding']]
    
    return data

# Directory containing the JSON files
directory = '../data/embedded'

# List to store all documents
documents = []

# Iterate through all JSON files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.json'):
        print(f"Processing {filename}")
        file_path = os.path.join(directory, filename)
        document = process_json_file(file_path)
        documents.append(document)

        # If we have 1000 documents, upload them in batch
        if len(documents) == 1000:
            result = search_client.upload_documents(documents)
            print(f"Uploaded {len(result)} documents")
            documents = []  # Clear the list for the next batch

# Upload any remaining documents
if documents:
    result = search_client.upload_documents(documents)
    print(f"Uploaded {len(result)} documents")

print("Data upload completed.")
# Out:
# Processing review_73.json
# Processing review_772.json
# Processing review_288.json
# Processing review_322.json
# Processing review_637.json
# Processing review_267.json
# Processing review_908.json
# Processing review_375.json
# Processing review_725.json
# Processing review_24.json
# Processing review_230.json
# Processing review_660.json
# Processing review_549.json
# Processing review_119.json
# Processing review_32.json
# Processing review_733.json
# Processing review_363.json
# Processing review_699.json
# Processing review_846.json
# Processing review_903.json
# Processing review_450.json
# Processing review_351.json
# Processing review_701.json
# Processing review_214.json
# Processing review_644.json
# Processing review_994.json
# Processing review_428.json
# Processing review_582.json
# Processing review_57.json
# Processing review_756.json
# Processing review_306.json
# Processing review_613.json
# Processing review_243.json
# Processing review_490.json
# Processing review_869.json
# Processing review_886.json
# Processing review_185.json
# Processing review_310.json
# Processing review_740.json
# Processing review_41.json
# Processing review_255.json
# Processing review_605.json
# Processing review_486.json
# Processing review_469.json
# Processing review_193.json
# Processing review_890.json
# Processing review_16.json
# Processing review_717.json
# Processing review_347.json
# Processing review_652.json
# Processing review_202.json
# Processing review_828.json
# Processing review_982.json
# Processing review_594.json
# Processing review_629.json
# Processing review_279.json
# Processing review_783.json
# Processing review_82.json
# Processing review_296.json
# Processing review_916.json
# Processing review_445.json
# Processing review_150.json
# Processing review_500.json
# Processing review_853.json
# Processing review_384.json
# Processing review_691.json
# Processing review_412.json
# Processing review_941.json
# Processing review_804.json
# Processing review_557.json
# Processing review_107.json
# Processing review_668.json
# Processing review_392.json
# Processing review_238.json
# Processing review_687.json
# Processing review_957.json
# Processing review_404.json
# Processing review_111.json
# Processing review_541.json
# Processing review_812.json
# Processing review_94.json
# Processing review_795.json
# Processing review_280.json
# Processing review_453.json
# Processing review_900.json
# Processing review_845.json
# Processing review_516.json
# Processing review_146.json
# Processing review_131.json
# Processing review_561.json
# Processing review_832.json
# Processing review_998.json
# Processing review_977.json
# Processing review_424.json
# Processing review_648.json
# Processing review_218.json
# Processing review_865.json
# Processing review_536.json
# Processing review_166.json
# Processing review_473.json
# Processing review_189.json
# Processing review_920.json
# Processing review_170.json
# Processing review_520.json
# Processing review_873.json
# Processing review_936.json
# Processing review_465.json
# Processing review_609.json
# Processing review_259.json
# Processing review_824.json
# Processing review_577.json
# Processing review_127.json
# Processing review_432.json
# Processing review_598.json
# Processing review_961.json
# Processing review_449.json
# Processing review_275.json
# Processing review_625.json
# Processing review_330.json
# Processing review_760.json
# Processing review_61.json
# Processing review_808.json
# Processing review_672.json
# Processing review_388.json
# Processing review_222.json
# Processing review_36.json
# Processing review_737.json
# Processing review_367.json
# Processing review_408.json
# Processing review_234.json
# Processing review_664.json
# Processing review_371.json
# Processing review_721.json
# Processing review_20.json
# Processing review_849.json
# Processing review_633.json
# Processing review_263.json
# Processing review_799.json
# Processing review_98.json
# Processing review_77.json
# Processing review_776.json
# Processing review_326.json
# Processing review_632.json
# Processing review_262.json
# Processing review_798.json
# Processing review_99.json
# Processing review_76.json
# Processing review_777.json
# Processing review_327.json
# Processing review_848.json
# Processing review_235.json
# Processing review_665.json
# Processing review_370.json
# Processing review_720.json
# Processing review_21.json
# Processing review_409.json
# Processing review_673.json
# Processing review_389.json
# Processing review_223.json
# Processing review_37.json
# Processing review_736.json
# Processing review_366.json
# Processing review_1.json
# Processing review_809.json
# Processing review_274.json
# Processing review_624.json
# Processing review_331.json
# Processing review_761.json
# Processing review_60.json
# Processing review_448.json
# Processing review_825.json
# Processing review_576.json
# Processing review_126.json
# Processing review_433.json
# Processing review_599.json
# Processing review_960.json
# Processing review_608.json
# Processing review_258.json
# Processing review_171.json
# Processing review_521.json
# Processing review_872.json
# Processing review_937.json
# Processing review_464.json
# Processing review_864.json
# Processing review_537.json
# Processing review_167.json
# Processing review_472.json
# Processing review_188.json
# Processing review_921.json
# Processing review_649.json
# Processing review_219.json
# Processing review_130.json
# Processing review_560.json
# Processing review_833.json
# Processing review_999.json
# Processing review_976.json
# Processing review_425.json
# Processing review_452.json
# Processing review_901.json
# Processing review_844.json
# Processing review_517.json
# Processing review_147.json
# Processing review_95.json
# Processing review_794.json
# Processing review_281.json
# Processing review_956.json
# Processing review_405.json
# Processing review_110.json
# Processing review_540.json
# Processing review_813.json
# Processing review_669.json
# Processing review_393.json
# Processing review_239.json
# Processing review_686.json
# Processing review_413.json
# Processing review_940.json
# Processing review_805.json
# Processing review_556.json
# Processing review_106.json
# Processing review_385.json
# Processing review_690.json
# Processing review_917.json
# Processing review_444.json
# Processing review_151.json
# Processing review_501.json
# Processing review_852.json
# Processing review_628.json
# Processing review_278.json
# Processing review_782.json
# Processing review_83.json
# Processing review_297.json
# Processing review_829.json
# Processing review_983.json
# Processing review_595.json
# Processing review_17.json
# Processing review_716.json
# Processing review_346.json
# Processing review_653.json
# Processing review_203.json
# Processing review_487.json
# Processing review_468.json
# Processing review_192.json
# Processing review_891.json
# Processing review_311.json
# Processing review_741.json
# Processing review_40.json
# Processing review_254.json
# Processing review_604.json
# Processing review_491.json
# Processing review_868.json
# Processing review_887.json
# Processing review_184.json
# Processing review_56.json
# Processing review_757.json
# Processing review_307.json
# Processing review_612.json
# Processing review_242.json
# Processing review_995.json
# Processing review_429.json
# Processing review_583.json
# Processing review_350.json
# Processing review_700.json
# Processing review_215.json
# Processing review_645.json
# Processing review_834.json
# Processing review_137.json
# Processing review_567.json
# Processing review_588.json
# Processing review_422.json
# Processing review_971.json
# Processing review_530.json
# Processing review_160.json
# Processing review_863.json
# Processing review_926.json
# Processing review_475.json
# Processing review_249.json
# Processing review_619.json
# Processing review_875.json
# Processing review_176.json
# Processing review_526.json
# Processing review_463.json
# Processing review_199.json
# Processing review_930.json
# Processing review_571.json
# Processing review_121.json
# Processing review_988.json
# Processing review_822.json
# Processing review_967.json
# Processing review_434.json
# Processing review_208.json
# Processing review_658.json
# Processing review_859.json
# Processing review_273.json
# Processing review_789.json
# Processing review_623.json
# Processing review_88.json
# Processing review_67.json
# Processing review_336.json
# Processing review_766.json
# Processing review_418.json
# Processing review_6.json
# Processing review_674.json
# Processing review_224.json
# Processing review_731.json
# Processing review_361.json
# Processing review_30.json
# Processing review_818.json
# Processing review_232.json
# Processing review_662.json
# Processing review_398.json
# Processing review_26.json
# Processing review_377.json
# Processing review_727.json
# Processing review_459.json
# Processing review_635.json
# Processing review_265.json
# Processing review_770.json
# Processing review_320.json
# Processing review_71.json
# Processing review_357.json
# Processing review_707.json
# Processing review_212.json
# Processing review_642.json
# Processing review_992.json
# Processing review_838.json
# Processing review_584.json
# Processing review_750.json
# Processing review_300.json
# Processing review_51.json
# Processing review_615.json
# Processing review_245.json
# Processing review_496.json
# Processing review_479.json
# Processing review_183.json
# Processing review_880.json
# Processing review_47.json
# Processing review_316.json
# Processing review_746.json
# Processing review_253.json
# Processing review_603.json
# Processing review_480.json
# Processing review_879.json
# Processing review_896.json
# Processing review_195.json
# Processing review_711.json
# Processing review_341.json
# Processing review_10.json
# Processing review_654.json
# Processing review_204.json
# Processing review_984.json
# Processing review_592.json
# Processing review_438.json
# Processing review_84.json
# Processing review_785.json
# Processing review_290.json
# Processing review_443.json
# Processing review_910.json
# Processing review_855.json
# Processing review_156.json
# Processing review_506.json
# Processing review_228.json
# Processing review_678.json
# Processing review_382.json
# Processing review_697.json
# Processing review_947.json
# Processing review_414.json
# Processing review_551.json
# Processing review_101.json
# Processing review_802.json
# Processing review_394.json
# Processing review_681.json
# Processing review_402.json
# Processing review_951.json
# Processing review_814.json
# Processing review_117.json
# Processing review_547.json
# Processing review_269.json
# Processing review_793.json
# Processing review_639.json
# Processing review_92.json
# Processing review_286.json
# Processing review_906.json
# Processing review_455.json
# Processing review_510.json
# Processing review_140.json
# Processing review_843.json
# Processing review_907.json
# Processing review_454.json
# Processing review_511.json
# Processing review_141.json
# Processing review_842.json
# Processing review_268.json
# Processing review_792.json
# Processing review_638.json
# Processing review_93.json
# Processing review_287.json
# Processing review_403.json
# Processing review_950.json
# Processing review_815.json
# Processing review_116.json
# Processing review_546.json
# Processing review_395.json
# Processing review_680.json
# Processing review_946.json
# Processing review_415.json
# Processing review_550.json
# Processing review_100.json
# Processing review_803.json
# Processing review_229.json
# Processing review_679.json
# Processing review_383.json
# Processing review_696.json
# Processing review_442.json
# Processing review_911.json
# Processing review_854.json
# Processing review_157.json
# Processing review_507.json
# Processing review_85.json
# Processing review_784.json
# Processing review_291.json
# Processing review_985.json
# Processing review_593.json
# Processing review_439.json
# Processing review_710.json
# Processing review_340.json
# Processing review_11.json
# Processing review_655.json
# Processing review_205.json
# Processing review_481.json
# Processing review_878.json
# Processing review_897.json
# Processing review_194.json
# Processing review_46.json
# Processing review_317.json
# Processing review_747.json
# Processing review_252.json
# Processing review_602.json
# Processing review_497.json
# Processing review_478.json
# Processing review_182.json
# Processing review_881.json
# Processing review_751.json
# Processing review_301.json
# Processing review_50.json
# Processing review_614.json
# Processing review_244.json
# Processing review_993.json
# Processing review_839.json
# Processing review_585.json
# Processing review_356.json
# Processing review_706.json
# Processing review_213.json
# Processing review_643.json
# Processing review_634.json
# Processing review_264.json
# Processing review_771.json
# Processing review_321.json
# Processing review_70.json
# Processing review_458.json
# Processing review_233.json
# Processing review_663.json
# Processing review_399.json
# Processing review_27.json
# Processing review_376.json
# Processing review_726.json
# Processing review_819.json
# Processing review_675.json
# Processing review_225.json
# Processing review_730.json
# Processing review_360.json
# Processing review_31.json
# Processing review_419.json
# Processing review_7.json
# Processing review_272.json
# Processing review_788.json
# Processing review_622.json
# Processing review_89.json
# Processing review_66.json
# Processing review_337.json
# Processing review_767.json
# Processing review_858.json
# Processing review_209.json
# Processing review_659.json
# Processing review_570.json
# Processing review_120.json
# Processing review_989.json
# Processing review_823.json
# Processing review_966.json
# Processing review_435.json
# Processing review_874.json
# Processing review_177.json
# Processing review_527.json
# Processing review_462.json
# Processing review_198.json
# Processing review_931.json
# Processing review_248.json
# Processing review_618.json
# Processing review_531.json
# Processing review_161.json
# Processing review_862.json
# Processing review_927.json
# Processing review_474.json
# Processing review_835.json
# Processing review_136.json
# Processing review_566.json
# Processing review_589.json
# Processing review_423.json
# Processing review_970.json
# Uploaded 999 documents
# Data upload completed.
